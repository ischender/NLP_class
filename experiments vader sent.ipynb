# %%
from csv import reader, DictReader, DictWriter
from langdetect import detect
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
import cld2

clean_up_re = re.compile('(\[[0-9]{4,4}-[0-9]{2,2}-[0-9]{2,2}\])? *[0-9]*(Food ordered:)?')

def clean_comment(comment):
    m = clean_up_re.match(comment)
    if m:
        comment = comment[m.span()[1]:]
    comment = comment.strip()
    return comment
    
def get_simple_label(label):
    return label.split(" ")[0]

def get_labels(el):
    labels = []
    for i in range(3):
        label = el[f'Topic {i+1}']
        #         print(label)
        if label:
            labels.append(get_simple_label(label))
    return labels
        
def mylang_detect(text):
    try:
        lang = detect(text)
    except:
        lang = "en"
    if lang not in ['en', 'de']:
        lang = cld2.detect(text)[2][0][1]
    if lang not in ['en', 'de']:
        lang = "en"
    return lang

# %%
csvdict = DictReader(open("/Users/aliosha/Downloads/Tagging.csv"), dialect='excel')

# %%
csvdict = DictReader(open("/Users/aliosha/Downloads/emails.csv"), dialect='excel')

# %%
email_list = []
for i, e in enumerate(csvdict):
    email_list.append(e)
    if i > 10000:
        break

# %%
email_list[1000:1010]
# Out:
# [OrderedDict([('file',
#                '9KQIX5rRWW4NXJjIWU9+KoXt3NBtMaZBPOavx4Xg1FqBPlbVUHHNRKT3Q0lfUo3R3pHIfvHqBUE+'),
#               ('message', None)]),
#  OrderedDict([('file',
#                '2KEtkZqxbyh1KyLgj2qjqkbPH8vbrWsZaaicNdCGGdw4lRsYI4rYu9QV7MMR86iseGFViGTz1xVm'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'GUbTuUHHFaKKM5asqwTG4kYlTWz4QVk8XaOqrx9ugz/38WscTKGfau09q1/Bkkh8WaPk8/boAfp5'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'i03sJbmh8W/+Shap/wBsf/RKVyRHeut+Ln/JQtU/7Y/+iUrlPSrh8KOobnI6gV6H8LbsS2N3YyfM'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'AwI+h4NefH2AroPh7eiw8QxByAsxKMKmotB3Eu9O/srxjHbuAE88EfjXr6Kfl9cCuS+IGiS3H2fU'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'bKMtPC65x3FdRaSO9jFJIpV/LBIPXOK5JO6QjyfWNM+0eNGtIBxJMOnp1NdN8R5EtNDtrJCBubp7'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'AVb8J6PJJqt3rF5GVZpCsW7sOlcr8RdQ+160YUI8u3XbxWi96SSA5ccdaMkNTc/jTl5rosO4r7W6'),
#               ('message', None)]),
#  OrderedDict([('file',
#                '1E3y9OlSOoAzTMCiwxmM00nAJx0p571VupljjJJx9aHZK5JI/wAw+8QAM1jXl8qXZX7ygdTTJtSk'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'kVkIIHQFazirOS25ifpXNOdwLc96WAdWK4BG0HANMhuZXwoccnueapzB2+UggD2pLcKX2bsN2NZD'),
#               ('message', None)]),
#  OrderedDict([('file',
#                'udDb3Ehw1wGRDwXXoKmF4I5AjMrqehrDkupUhMTyZz1A6VGJZFIlDBtvamm0wudWjpKgMbhvUKel'),
#               ('message', None)])]

# %%
corpus = []
for el in csvdict:
    comment = clean_comment(el['comment'])
    labels = get_labels(el)
    score = el.get('score')
    if comment and labels:
        item = {"comment":comment,
               "labels":labels,
               "score":score}
        corpus.append(item)

# %%
len(corpus)
# Out:
# 1083

# %%
corpus[:10]
# Out:
# [{'comment': "We ordered two curries and one soup. The curries arrived in bowls and were already mixed with the rice, which gave them the consistency of a watery soup. This wouldn't have been a big deal if they'd at least tasted good. But they didn't. The soup tasted so bad we simply threw it away.",
#   'labels': ['PROD'],
#   'score': 'Negative'},
#  {'comment': 'Tuna Lemon Sandwich was a fairly small one – for the regular price way too small. Bread was already very dry on one side, felt like from the day before. Not inviting to order again.',
#   'labels': ['PRICE', 'PROD', 'QA'],
#   'score': 'Negative'},
#  {'comment': 'Had a chicken burrito for lunch and it was the bomb!',
#   'labels': ['PROD'],
#   'score': 'Positive'},
#  {'comment': 'one salad was missing', 'labels': ['QA'], 'score': 'Positive'},
#  {'comment': 'falscher Burrito', 'labels': ['QA'], 'score': 'Positive'},
#  {'comment': 'too late', 'labels': ['DEL'], 'score': 'Neutral / mixed'},
#  {'comment': 'The wrap finally arrived, soggy and mushy. And the order was delated',
#   'labels': ['PROD', 'DEL'],
#   'score': 'Negative'},
#  {'comment': 'Vegan Waldorf was great, Avocado BLT was great.',
#   'labels': ['PROD'],
#   'score': 'Positive'},
#  {'comment': 'But because the wrap is packed so small, there is a lot of bread / wrap in one bite and not a lot of fresh ingredients',
#   'labels': ['PROD'],
#   'score': ''},
#  {'comment': 'Salat vom Vortag in den Kühlschrank getan und am nächsten Tag mit Schimmel',
#   'labels': ['QA'],
#   'score': 'Negative'}]

# %%
import textacy
import spacy
import textblob
import textblob_de

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores("hey")
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(comment):
    sentiment_values = analyzer.polarity_scores(comment)

    if sentiment_values['compound'] > 0.5:
        return 'pos'
    elif sentiment_values['compound'] < -0.5:
        return 'neg'
    else:
        return 'neu'

    
# test_score = {'compound': 0.9551, 'neg': 0.0, 'neu': 0.645, 'pos': 0.355}
# get_sentiment(test_score)

# %%
textblob.TextBlob("not a kill review").sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
def get_emotion_polarity(text, lang=None):
    if not lang:
        lang = mylang_detect(text)
    if lang == "en":
        tb = textblob.TextBlob(text)
    else:
        tb = textblob_de.TextBlobDE(text)
#     ts = doc_text[i]
#     em = textacy.lexicon_methods.emotional_valence(ts)
    return tb.sentiment.polarity


def get_emotion(text, lang=None):
    polarity = get_emotion_polarity(text, lang)
    if polarity < -0.05:
        emotion = "negative"
    elif polarity > 0.05:
        emotion = "positive"
    else:
        emotion = "neutral"
    return emotion


def create_corpus(csvdict):
    corpus = []
    for el in csvdict:
        comment = clean_comment(el['comment'])
        labels = get_labels(el)
        if comment:
            item = {"comment":comment,
                   "orig_labels":labels,
                   "orig_posit":el['+ / -']}
            corpus.append(item)
    return corpus


def predict_labels(text):
    return get_labels_from_dict(magpie.predict_from_text(text))

# %%
csvdict = DictReader(open("/Users/aliosha/Downloads/Tagging.csv"), dialect='excel')
my_dict = list(csvdict)
len(my_dict)
# Out:
# 1276

# %%
element = my_dict[10]
element
# Out:
# OrderedDict([('id', 'int000011'),
#              ('date', '2017-08-03'),
#              ('brand', 'EarlsDeli'),
#              ('score', 'Neutral / mixed'),
#              ('source', 'internal'),
#              ('channel', 'NA'),
#              ('location', 'Xberg'),
#              ('comment', 'wrong sandwich'),
#              ('+ / -', 'negative'),
#              ('Topic 1', 'QA –\xa0Missing or wrong products / ingredients'),
#              ('Topic 2', ''),
#              ('Topic 3', ''),
#              ('Questions', '')])

# %%
corpus = create_corpus(my_dict)
corpus[:10]
# Out:
# [{'comment': "We ordered two curries and one soup. The curries arrived in bowls and were already mixed with the rice, which gave them the consistency of a watery soup. This wouldn't have been a big deal if they'd at least tasted good. But they didn't. The soup tasted so bad we simply threw it away.",
#   'orig_labels': ['PROD'],
#   'orig_posit': 'negative'},
#  {'comment': 'Tuna Lemon Sandwich was a fairly small one – for the regular price way too small. Bread was already very dry on one side, felt like from the day before. Not inviting to order again.',
#   'orig_labels': ['PRICE', 'PROD', 'QA'],
#   'orig_posit': 'negative'},
#  {'comment': 'Had a chicken burrito for lunch and it was the bomb!',
#   'orig_labels': ['PROD'],
#   'orig_posit': 'positive'},
#  {'comment': 'one salad was missing',
#   'orig_labels': ['QA'],
#   'orig_posit': 'negative'},
#  {'comment': 'falscher Burrito',
#   'orig_labels': ['QA'],
#   'orig_posit': 'negative'},
#  {'comment': 'too late', 'orig_labels': ['DEL'], 'orig_posit': 'negative'},
#  {'comment': 'The wrap finally arrived, soggy and mushy. And the order was delated',
#   'orig_labels': ['PROD', 'DEL'],
#   'orig_posit': 'negative'},
#  {'comment': 'Vegan Waldorf was great, Avocado BLT was great.',
#   'orig_labels': ['PROD'],
#   'orig_posit': 'positive'},
#  {'comment': 'But because the wrap is packed so small, there is a lot of bread / wrap in one bite and not a lot of fresh ingredients',
#   'orig_labels': ['PROD'],
#   'orig_posit': 'negative'},
#  {'comment': 'Salat vom Vortag in den Kühlschrank getan und am nächsten Tag mit Schimmel',
#   'orig_labels': ['QA'],
#   'orig_posit': 'negative'}]

# %%
for el in corpus:
    if el.get('orig_posit') not in ['positive', 'negative']:
        print(el.get('orig_posit'), get_sentiment(el['comment']), get_emotion(el['comment']), el['comment'])
# Out:
# n/a neu neutral Food Ordered:
# n/a neu neutral (ops, we were hungry and are not foodies, we forgot to take pictures... next time, promise)
# n/a neu neutral Orded #36787
# n/a neu neutral * We got called letting us know that our payment option (cash, €50 bill) wouldn't work, also there was no change. If cash is not an option, maybe the checkbox for it shouldn't be visible?
# n/a neu neutral Yellow Pizza with Huhnchen
# n/a neu negative Hey green gurus,
# n/a neu negative I just ordered the Veggie Thunder Quesadilla with:  Black Beans, extra cheddar, guacamole.
# n/a neu positive Liebe GreenGurus,
# n/a pos positive POSITIVE:
# n/a pos positive Positive
# n/a neu negative Hello Green Gurus Team,
# n/a neu neutral Hallo Greengurus,
# n/a neu neutral https://gurucollective.zendesk.com/agent/tickets/8574
# n/a neu positive **There is a glitch in your ordering system!!--->> I was able to order a soda as an add-on and was not charged for it.  Also I could add bread and croutons for no extra charge (not sure if there is normally an extra charge for them...)
# n/a neu neutral order number 1709071874761
# n/a neu neutral Huhu Zusammen,
# n/a neu neutral Aargh!
# n/a neu negative Got the chicken burritos and quesadillas.
# n/a neu neutral Ihre Gesamtbewertung von 0 bis 5: <U+2605><U+2605><U+2605><U+2605><U+2605>
# n/a neu negative I ordered twice: Pizza White, Pizza Green & Pizza Funghi + Tonno Salad
# n/a neu neutral "Wunschburrito" + Tortilla Chips with Guacamole. Advice:
# n/a neu negative es ist nun wieder passiert, dass meine Bestellung nicht richtig geliefert wurde!
# n/a neu negative Delivery too late because of not enough drivers but people were generally understanding when I called them in advance.
# n/a neu neutral Ich habe heute Hokkaido Ramen bei eurem Ramenlab bestellt.
# n/a pos positive Another Customer who ordered during afternoon break and didn't pay attention to our working hours. This happens frequently, is it possible to make that more clearly on the website by any chance?
# n/a pos positive The kitchen was understaffed for this amount of orders but everybody gave their best to keep the production going.
# n/a neu neutral I ordered the avocado pulled pork burger.
# n/a neu neutral Ordered an Avocado Burger with Jalapeños and Cheese, as well as Coleslaw.
# n/a neu neutral Ihre Gesamtbewertung von 0 bis 5: <U+2605><U+2605><U+2605>
# n/a neu neutral Hello gurus,
# n/a neu positive [Thai Curries] Peaceful Panang // Kaeng Phanaeng (pikant), mit Sesam-Tofu, mit Cashew-Kerne, TASTE NIRVANA Real Coconut Water - Pure 0,28l, Apinya Thai Chili Sauce (Original).
# n/a pos positive good sunday shift although one driver didn't show up. everybody worked well together.
# n/a neu neutral [FOOD ISSUE] [PACKAGING ISSUE] [TIME ISSUE] [2017-10-08] Test from Eugene
# n/a neu neutral [FOOD ISSUE] [2017-10-15] Customer via FB: "Absolute Frechheit, die ich so noch nicht erlebt habe. Wir haben 2x Sweet Potato Wrap, Waldorf Bowl und Amigo Bowl bestellt.
# n/a neu negative [FOOD ISSUE] [TIME ISSUE] [2017-10-18] For me, Tom Kha and Thai-Curry - Mean Green Rindfleisch (for a friend, Reckless Red  Sesam-Tofu).
# n/a neu neutral I ordered the chilli cheeseburger with pork and texan potato salad.
# n/a neu positive Ordered the classic with vegan chorizo and coleslaw.
# n/a neu neutral [FOOD ISSUE] [2017-10-23] HI,
# n/a neu neutral [FOOD ISSUE] [2017-10-19] Food ordered:
# n/a neu neutral [FOOD ISSUE] [2017-10-25] Food ordered:
# n/a neu positive [TIME ISSUE] Customer happy about us calling him to explain delay in delivery (didn't take it for granted)
# n/a neu neutral [FOOD ISSUE] Driver issue [2017-10-27] Food ordered:
# n/a neu neutral [FOOD ISSUE] [2017-10-29] Food ordered:
# n/a neu positive Ordered the Sweet Potato Wrap and the Eureka Bowl.
# n/a neu neutral Bestellt wurden ein Korma- und Butter Curry sowie ein veganer Chili Cheese Burger und eine Tokio Ramen Suppe.
# n/a pos positive [FOOD ISSUE] [2017-10-09] They were out of something that I ordered but they called me very quickly, offered another option and were really great about it.
# n/a neu positive [TIME ISSUE] Too many delays and grumpy customers due to massive order amount and too less drivers
# n/a neu neutral I ordered the Beef Raider (pikant) burrito and Sundance quesadillas.
# n/a pos positive The only is that the chicken burrito was better than beef. And also the wrapped one is better then the bowl
# n/a neu neutral [FOOD ISSUE] [2017-11-05] Food ordered:
# n/a neu neutral Chrorizo Dynamite Burrito
# n/a neu positive Every thing went smooth today. Thanks a lot!
# n/a neu neutral [FOOD ISSUE] [2017-11-06]
# n/a neu positive Immer top. Alles!
# n/a neu positive An sich gut, aber “build your own“ ohne (sichtbare) Möglichkeit Fleisch zu wählen.
# n/a neu positive Insgesamt gut, Checkout besser als früher, aber immer noch ein Checkout mit vielen Schritten
# n/a neu positive Ich mag den Konzept
# n/a neu neutral User interface on the website is pretty poor. Also seems like a flaw in the business model that the the minimum spend for delivery exceeds the price of one main meal.
# n/a neu neutral Wann gibt es neue Gerichte?
# n/a neu neutral Bestellungsprozess klappte nicht beim ersten Mal
# n/a neu negative Weil der Prozess nicht fehlerfrei funktionierte
# n/a neu neutral Geschmack und Qualität des Essens
# n/a neu neutral Ich hab schon emfohlen.
# n/a neu positive Hat mal gut geklappt, dann wieder nicht. Jetzt sind wir in einer neuen Testphase.
# n/a neu neutral Warum nicht?
# n/a neu positive aber sonst alles prima.
# n/a pos positive Not a big fan of Mexican food. However you guys are doing a great job!
# n/a pos positive I got an extra drink! It was so nice!
# n/a neg negative Bei Lieferung ins Büro ist man gewohnt bar zu bezahlen. Die anderen Zahlungsarten waren jetzt etwas kompliziert zu managen.
# n/a pos positive Keep up the great work!
# n/a neg negative Ich finde es schade, dass die Auswahl nicht mehr so groß ist wie vorher.
# n/a neu positive Alles top
# n/a pos positive because I rarely speak about things unless I'm incredibly passionate about it.
# n/a neu neutral zu viele Schritte und Klicks
# n/a neu neutral Test von Rike
# n/a pos positive Einfach super service
# n/a neu negative Bin nicht interessiert daran Spam auf meinem Handy zu erhalten nachdem ich Essen bestellt habe.
# n/a pos positive Super, macht weiter so. Aber bitte wechselt Eurer Salate auch mal durch - und wenn nur einen Teil. Es ist etwas eintönig wenn man regelmäßig bestellt. LG
# n/a neu neutral Bezahlung mit paypal hat nicht funktioniert
# n/a neu negative Das erste mal war das Essen ganz ok. Nicht überwältigend, aber ok.
# n/a neu positive Weil mein Essen noch nicht da ist. Wenn das richtig gut ist, würde ich auch ne 10 geben. weiß ich ja aber noch nicht.
# n/a neu positive Bin mir unsicher, ob das Essen pünktlich ankommt, wenn gleich noch ein Tracking angeboten wird. Oder gibt es ein Zeitfenster? Das wäre nachvollziehbarer. Sonst allet schick!!!
# n/a neu positive Gerichte bitte öfter abwechseln
# n/a neu positive mega verschlechtert. am Anfang habe ich euch geliebt
# n/a neg negative Alles funktioniert gut, nur schade, dass so viel ausverkauft ist! Ich hätte gern einen Smoothie gekauft, aber es war keine Sorte bestellbar.
# n/a neu positive Alles TOP!
# n/a neu negative Terrible customer service at times
# n/a neu negative Irgendwie umständlich.
# n/a neu positive mehr abwechslung bitte :)
# n/a neu positive War alles gut :)
# n/a neu positive Checkout has too many steps from my perspective + I am not automatically logged in with my account
# n/a neu neutral Ich hatte per Pay PAL im Voraus bezahlt.
# n/a neu negative Sortiment nicht groß und wechselt zu selten
# n/a neu positive Alles top!!!
# n/a neg negative Very bad experience / english not working / Product descriptions wrong
# n/a pos positive would like to see better drinks options, coconut and other green juices
# n/a neu positive Finally new salads!!!
# n/a neg positive Wir haben lange bei Deliveroo gesucht, bis wir ein Resaurant gefunden haben, dass ein Gericht für unsere Ernährungsweise anbietet und waren froh die Bowls mit Quinoa gefunden zu haben.
# n/a neu neutral My "carrot ginger stew" turned into "coco spinach stew" after i paid??????????
# n/a neu neutral needs somethi g to add
# n/a neu neutral alles sooooo toll! <f0><U+009F><U+0099><U+008F><f0><U+009F><U+008F><U+00BC>
# n/a neu neutral herrrrrrrlich
# n/a pos positive Schön, dass ihr endlich neue Salate habt. Bitte wartet nicht wieder ewig, bis ihr diese wechselt. Mein Tip, ein paar als Standardsortiment und einige immer varierend. Pro Woche oder alle 2 Wochen. Ärgerlich ist auch teilweise, dass Montags immer alles ausverkauft ist .... ABER IHR SEID SUPER!
# n/a neu neutral das essen entsprach in keinster weise den fotos und der beschreibung bei deliveroo
# n/a neu positive wundervoll
# n/a neg negative Ihr liefert leider nicht mehr zu meiner Wohnung in 13355. Die neuen Preise sind deutlich über einem normalen Lunch Budget in Berlin. Das ist sehr schade.
# n/a pos positive alles super
# n/a neu neutral Wir haben schon einmal bei euch bestellt und waren zufrieden.
# n/a neu neutral Nicht jede Woche gibt es Bowls, die eine 10 verdienen, aber eine 8 doch allemal :)
# n/a neu negative Liefergebiet wurde zu stark eingeschränkt
# n/a neu neutral !
# n/a neu neutral Übersichtlich, leichter Bestellvorgang mit dem Handy
# n/a neu neutral Hey, ich habe mit meinem Mann zusammen schon desöftern bestellt bei euch.
# n/a neg negative Ich habe erst versucht im Safari Browser 10.1.2 auf Mac OSX zu bestellen, konnte aber im Regstrierungsformular meine Daten nicht richtig eingeben weil der Inhalt der Eingabefelder unlesbar war. Dann habe ich es mit Chrome versucht und da hat es problemlos geklappt. War halt ziemlich umständlich.
# n/a neu neutral Hups wollte 10 klicken
# n/a neu neutral Weil es sehr wahrscheinlich ist, dass ich den Online-Shop weiterempfehlen werde.
# n/a neu negative Weil ich seit fast 5 Monaten vergeblich versuche Ihnen mitzuteilen das Sie eine falsche Mobilnummer gespeichert haben mich aber immer wieder mit Ihren SMS belästigen und meine Hinweise darauf prima ignorieren! Mahlzeit.
# n/a neu neutral Senden sie mir nie wieder eine Nachricht
# n/a neu positive Toll, dass Ihr wieder liefert!
# n/a neg neutral Gestrigen Order war eine Katastrophe und wurde reklamiert.
# n/a pos neutral Service und Support war super. Nur beim Telefon geht nie jemand ran ;-)
# n/a neu positive Top
# n/a neu positive Übersichtlicher Shop, gute Bilder. Mal sehen, ob das Essen so lecker ist wie es aussieht
# n/a neu neutral Abzocke
#  neu neutral <f0><U+009F><U+0091><U+008C><f0><U+009F><U+008F><U+00BD>
# n/a neu neutral Der Service ist super, die Preise mit dem Officedeal okay.
# n/a neu negative Terrible.
# n/a neg neutral Es war genau die Art von Pizza, die ich gesucht hatte.
# n/a neg positive Die Auswahl ist nicht riesig und es sind viele Zutaten dabei, die Blähungen verursachen. Das ist im Business nicht so gut. ;-)
# n/a neg negative One of the worst meals ive had in berlin
# n/a neu neutral Wir würden Geld dafür zahlen, dass Menschen nicht hingehen oder der Laden geschlossen wird.
# n/a neu neutral Ich rede mit Freunden nicht unbedingt über das, was ich mal essenstechnisch bestellt hab.. daher ist es eher unwahrscheinlich, dass es zu einer Weiterempfehlung kommt. Wenn es Thema sein sollte, spricht nichts dagegen. Bin sehr zufrieden!
# n/a neu negative Der Checkout Prozess ist unübersichtlich und verwirrt mich.
# n/a neu negative Zu unübersichtlich und der vorgewählte Newsletter-SignUp ist extrem unfair und nervig.
# n/a neu positive Alles tip top!
# n/a neu negative It was terrible.
# n/a neu neutral Weil es weit von jeglichen exotischen Vorstellungen auf dieser Erde gelegen hat. Nicht von dieser Welt urgghhhhh.
# n/a neu positive ist gut, aber ist schon viel teurer geworden - eigentlich nicht mehr was für jeden Tag.
# n/a neu negative Sorry guys, but this was nothing
# n/a neu neutral Wahrscheinlich empfehle ich Euch meinen Arbeitskolleg*innen weiter :-)
# n/a neu positive Site looks good so far
# n/a neu neutral Checkout ist etwas mühsam
# n/a neu neutral Weil es sehr wahrscheinlich ist, dass ich GG an meine arbeitskolleg*innen weiterempfehle!
# n/a neu positive Gut
# n/a neu negative Ok.... aber nicht außergewöhnlich gut oder so
# n/a pos positive Super lunch food
# n/a neu positive Anruf bekommen: Tortillas würden zu spät kommen, danke für's Bescheid geben! Toll!
# n/a neu negative I already dilled the survey yesterday. Today i received another. If you keep sending me sms withbsurvey links, ill never ever buy your food. Please stop! Its super annoying
# n/a neu positive :)
# n/a neu positive detailed, easy process
# n/a neu neutral Weil ich nicht oft essen bestelle und auch niemandem diesbezüglich Empfehlungen gebe
# n/a pos positive Everything perfect!
# n/a neu neutral Woher haben sie meine Nummer???
# n/a neu neutral No sms please
# n/a neu positive Top!
# n/a neu neutral Es war ganz ok. Vom Guru-Collective das bisher beste, was ich bekommen habe. Aber richtig gut ist leider nach wie vor anders.
# n/a neu neutral Vergleich von Bowls (Zutaten, Nährwerte) nur über das Öffnen mehrere Tabs möglich. Angebot wechselt nicht so häufig. Keine Möglichkeit Dressings auszutauschen (insbesondere wenn Knoblauch enthalten ist)
# n/a neu positive Guter Und freundlicher Kundenservice.
# n/a neu neutral Brühe okay, Ei auch (chicken und beef).
# n/a neu neutral ihr seid schbitze
# n/a neg neutral Stop spamming!
# n/a pos positive I was happy with my bowl. However, there were several mix ups, which were handled promptly by the customer service - but still took away from the overall satisfaction of my order.
# n/a neu neutral Weil es toll ist
# n/a neu negative Besteelprozess etwas verwirrend
# n/a neu neutral Ich habe mich schon über facebook gemeldet:
# n/a neu neutral Preis-Leistung
# n/a neu neutral Sehr intuitive Website. Einfacher und übersichtlicher Bestellvorgang!
# n/a pos positive nicht SUPER tasty - aber gesund
# n/a neu positive alles einfach und kein versandkosten!
# n/a neu positive Ihr seid toll!!!
# n/a neu positive Wann gibt es mal wieder andere Salate? Etwas mehr abwechslung ist erwünscht.
# n/a pos positive The site is somewhat buggy; English translations do not always activate, I'd prefer promo code emails to have the option for English, and I'd love to modify my order too.  Aside from that, the service is great!
# n/a neg neutral Bug report: Die Bestätigung deiner Bestellung wurde an {{ email }} gesendet. Sobald deine Bestellung unterwegs ist, erhältst du einen Tracking-Code per SMS.
# n/a neu neutral Könnt ihr bitte bald mal wieder neue Salate in euer Angebot bringen? Langsam hängt mir das echt zum Hals raus immer das gleiche zu essen. Ihr hatte im letzten Jahr so viele verschiedene und vor allem gute Salate (z.B. der mit Grünkohl vor einem Jahr). Also tut euch und euren Kunden doch den Gefallen und bietet mal wieder etwas anderes an.
# n/a pos neutral weil ich euch super finde!!!
# n/a neu neutral Keine Barzahlung möglich :(
# n/a neu neutral Hi,
# n/a neu positive Weil ich euch schon mehrfach weiter empfohlen habe ;)

# %%
analyzer.polarity_scores("wrong sandwich")
# Out:
# {'compound': -0.4767, 'neg': 0.756, 'neu': 0.244, 'pos': 0.0}

# %%
def translate(rev):
    if rev == "pos":
        return "positive"
    if rev == "neg":
        return "negative"
    return "neutral"

def are_equal(rev1, rev2):
    if translate(rev1) == rev2:
        return True
    return False
        

for el in corpus:
    if not are_equal(get_sentiment(el['comment']), get_emotion(el['comment'])):
        print(el.get('orig_posit'), get_sentiment(el['comment']), get_emotion(el['comment']), el['comment'])
# Out:
# negative pos negative Tuna Lemon Sandwich was a fairly small one – for the regular price way too small. Bread was already very dry on one side, felt like from the day before. Not inviting to order again.
# positive pos negative Had a chicken burrito for lunch and it was the bomb!
# negative neu negative one salad was missing
# negative neu negative falscher Burrito
# negative neu negative too late
# negative neu negative wrong sandwich
# negative neu negative Mild Massaman was cold, had no sweet potato, hardly any rice. Seemed to be peanut butter sauce with green beans only.
# negative neu negative The customer ordered a vegan burrito bowl and some extras. The order got delivered after more than one hour. The bowl was half empty, beans were missing as well as at least three extras.
# negative neu negative ein Salat wurde vergessen
# negative neg positive Only thing: the customer complaints about the packaging of the burritos, which is not environmental friendly / sustainable.
# negative neu negative The customer ordered the Mean Green Curry and complaints that she basically got a "watery soup with rice". A tiny little bit of aubergine. The ordered extras (nuts) were missing. Besides the order got delivered with a delay. Order got refunded and the customer will get offered a free order on us.
# negative neu negative Brot zu den Salaten vergessen. Passierte wohl schon öfter
# negative neu positive the delivery took over 1h and the noodles were really way too spicy.
# positive neg neutral Beets & Avocado Sandwich war sehr lecker !
# negative neu positive The customer order a "build your own"-curry and complaint that the meat was tough and gristly, that the curry-sauce was not spicy/aromatic and that the rice was more porridge-like. The order got refunded and the customer got offered a free order on us.
# negative neg positive The customer ordered a "build your own" burrito. The order came after 1,08 h. The customer complaint, that he didn't got informed about the delay, only after calling the customer service. The burrito wasn't properly packaged, so the sauce was completely spilled out (and it was curry sauce, which wasn't supposed to be in the burrito). The customer got a refund and a make-up-order.
# negative neu negative eine falsche Bowl geliefert
# negative neu negative but the edges were a bit burned. Furthermore the red paprica, the cherrytomatos and the onions were missing.
# positive neu positive Red Pizza tasted really nice,
# negative neu negative You keep sending me SMS messages that I suppose to use to give you feedback but those links simply don't work. When I click on the link it says "Survey not found"n one of the previous times I ordered 2 salads and 2 smoothies, but you put only one smoothie in the bag, even though I payed for that smoothie.
# negative neg positive leider war der von mir gewünschte Waldorf Salat bei der Lieferung heute plötzlich ausverkauft. Der Fahrer war sehr nett & im Grunde alles drumherum sehr gut, aber die zwei Salate, die ich dann zur Auswahl hatte (Nicosia & Amigos) waren dann gar nicht so meins
# negative neu negative falsche Suppe wurde geliefert
# negative neu negative falscher Salat und ohne Smoothie (vielleicht Tüte verwechselt)
# negative neu positive Customer wasn´t satisfied with the delivered goods. From what he saw on the photo on the website, he was expecting to have more aubergine in his curry and some basil leaves, as he saw on the photo. He says, that was not what he got delivered.
# negative neg neutral Google Review: The customer complaints about his ordered curry. He describes it as only consisting of rice and spicy sauce – no herbs, no vegetables. Tone of customer: Do not order here, I wouldn't recommend this restaurant. Google review got answered.
# negative neu positive -star-rating on Google Reviews: Customer is satisfied with his order and the taste of the burrito. Only complaints about the burrito not being delivered that hot and the portion of the ordered tortilla chips and guacamole being too small. All in all positiv tone.
# negative neu negative Ein Smoothie wurde vergessen
# negative neu negative Cheese & Onion / Yellow Beets came in half a loaf of ciabatta each, so generally the wrong bread. Wrapping paper had burn marks. Yellow Beets features very little toppings and no sauce, so it’s too dry. When fixing that, it could become a winner …
# negative pos negative Customer: "If you like cold burritos that taste like nothing this is the one for you! 1 star for not being disgusting." Customer review got answered (Google).
# negative neu positive They had forgot the soup with the order, but the delivery person went back for it (they had realised the order was incomplete already, and went and got the soup quite quickly).
# positive pos neutral Very yummy! But the Vegan Waldorf had green beans instead of the chickpeas.
# negative pos negative Food was supposed to arrive 1 hr after ordering, received a call 1:05h after ordering with the info that it arrives in 20-30 minutes, but still had to wait another 60 minutes. Food arrived completely cold, box was soaked and the amount of food was so so so little. When i opened the box my coworkers actually started laughing because it looked like 3 spoons of food and tbh like someone already ate of it. Definitely had way bigger portions the times I ordered before -> Actually needed a second "lunch". Further, tomatoes were missing + there were no more chips?
# negative pos negative Food was supposed to arrive 1 hr after ordering, received a call 1:05h after ordering with the info that it arrives in 20-30 minutes, but still had to wait another 60 minutes. Food arrived completely cold, box was soaked and the amount of food was so so so little. When i opened the box my coworkers actually started laughing because it looked like 3 spoons of food and tbh like someone already ate of it. Definitely had way bigger portions the times I ordered before -> Actually needed a second "lunch". Further, tomatoes were missing + there were no more chips?
# negative neu negative The salad was unfortunately the wrong one (by that time it was the avocado salad with the onions without bacon but with Radieschen and co) -> I received the one with bacon (luckily I don't mind eating pork, but since the bacon has an extremely strong taste i could imagine a lot of people being quite pissed about that) plus there was only green salad. Also the dressing was a  completely different one, like a lemon one instead of honey mustard.
# negative neu positive Broccoli soup need a lot of improvement - too salty and does not taste very good. Sandwiches (BLT) are good, but one side was burnt and spoiled the taste. Also it is better to cut tomatoes into smaller pieces as it is not comfortable to eat half of tomato at once.
# positive neu positive The soup was very nice, spicy and tangy.
# negative neu negative First thing --The soup was too tangy for me. I like tangy, but not this level of tangy. The consistency was a bit weird for me. The creaminess seemed "inauthentic" in some way, not sure how else to describe it.
# negative neu negative Ordered the white pizza, it came cold even though the delivery is from two blocks away.
# n/a neu negative Hey green gurus,
# positive neu positive ich mag Ihre Gerichte sehr
# negative neu positive You won't be surprised to know that my delivery never made it.
# positive neu positive Delivery within an hour, so thumbs up! I had the mellow yellow curry and the moody soup. For the taste: Both were not bad, but I thought both of the dishes had a little sour-ish undertone, dont know from what though. Not as if they were bad, but from some ingredient. Besides that, not too mild, not too salty! :)
# negative pos neutral came a bit late (15'), was very friendly, dish was not hot anymore, big portion,
# negative neu positive coconut water has not been delivered (I got two soft drinks instead, so I can`t complain :) ), dish was hot, nuts were missing, "pikant" which I guess would be the medium-spiced version was already quite spicy :D, driver was on time and friendly
# n/a neu negative I just ordered the Veggie Thunder Quesadilla with:  Black Beans, extra cheddar, guacamole.
# negative pos negative It's difficult with this sandwich because you don't see the ingredients so you have no wow effect. You could find a sexier bread to boost the positive impression when seeing the sandwich.
# negative neu positive The Orange Pizza wasn't good to be honest. The ham was burned. This kind of pizza is rather meant to be eaten in the restaurant directly, not delivered.
# positive neu positive The soup was delicious, but came in a glass jar from spoonysoups.de (I don't know it this was the plan).
# negative neg neutral Avocado Burger with vegan Chorizo: vegan Chorizo is more spicy than expected and didn't look great mixed and mushed up with the guacamole, see picture. Rather boring burger overall.
# n/a neu positive Liebe GreenGurus,
# negative neu positive Amigo Bowl: Dressing isn't that great, very sour and watery. The bowl would have been nicer without it.
# negative neg positive Guacemole wurde leider vergessen. Als regulärer Kunde wäre ich insgesamt unzufrieden gewesen. Portion etwas klein. Die Aufteilung der Take-Away Schale ist etwas unvorteilhaft, da in der zweiten Kammer nur etwas Eisbergsalat und ein paar Tacos sind, diese aber trotzdem 40% der Schale ausmachen.
# positive neu positive Leckere Chipotle Majo! Essen kam sehr schnell von Refael. Hab 5 Sterne bei Lieferando gegeben.
# negative neu positive I ordered the Antipasti Wrap: It mostly consisted of spinach. There was no mozzarella in it instead I found some gouda kind of cheese. Plus there was only like half of a little tomato and artichoke in it. Wouldn't order it again.
# n/a neu negative Hello Green Gurus Team,
# negative neu negative Cold, slow and not enough, bu packaging was better than before at least
# negative neu negative Took 1 hour to get delivery and pizza was cold
# n/a neu positive **There is a glitch in your ordering system!!--->> I was able to order a soda as an add-on and was not charged for it.  Also I could add bread and croutons for no extra charge (not sure if there is normally an extra charge for them...)
# negative neu positive The pizza was a bit too dry for the price, needs a bit more juiciness.
# negative neu negative The Green Pizza was yummy, but to me it's not worth 8.50€. And 2€ for a few leaves of rucola?!
# negative neu positive , but curry not that good. there was almost no spinach and it would be better with the rice on the side instead of mixed in already.
# positive neu positive quick delivery
# negative pos neutral Ordered 3 soups. Taste is great but too small. Even the 3 soups didn't fill me up. Hence too expensive. Were lukewarm as well.
# positive neg positive Mein Avocado Burger mit Jalapenos war sehr lecker, schön viel Avocado, gute Schärfe und das weiche Brot gefiel mir auch.
# negative neg neutral Die Kartoffelsalat-Beilage allerdings gefiel mir gar nicht, die Kartoffeln waren quasi ro un es waren keine grünen Bohnen dabei wie versprochen. Daher neutral. Burger gut, Beilage schlecht.
# negative neu negative Smoothie und Brot wurden vergessen
# negative neu positive Vegan Waldorf Bowl: The grapes weren't good anymore, they were brown and too soft at the front (seem old) and the dressing was very very watery, not how it usually is!
# negative neu negative , but cold and little too dry
# negative neu negative Order number: 3760 - In the salad, there was no parmesan chips. And there was just one small piece of avocado in it.
# negative neu positive I ordered Avocado Burger with pulled pork. While I liked this particular combination of the ingredients, I still don't really like the bread you use. It tasted old and artificial. I really like the onions and avocado, though the portion of guacamole was really small (and I ordered an extra one!).
# negative neu negative ein paar bowls wurden vergessen
# negative neg neutral Brot hat gefehlt. Die Portion war zu klein!
# negative neu negative customer ordered a bowl and received a burrito, which happens for the 2nd time in a few days already. She is gluten intolerant and has stated that in the order.
# negative neu negative didn´t receive chips, nobody asked her, if that´s ok, or if she would like to have something instead and she was frustrated and disappoointed.
# positive neu negative chicken burrito, vegan burrito.  but the delivery person said that my house was "difficult to find". He claimed my address was incomplete. My address and name WERE complete on my Lieferheld order. Apparently, the person that had transcribed my information from the computer to a handwritten piece of paper had failed to include my full address and that the name on the bell is different from my name. The chicken burrito was good for a Berlin burrito. The vegan burrito was a bit small. The packaging was really nice.
# negative pos negative I'll focus on the negative, as this is what can help you improve: the burritos (one vegan one, one veggie one) tasted very bland. I was joking that the name GringoBurritos makes a lot of sense because those certainly are no real burritos. I think you can make them much tastier and spicier. Also the added Guacamole was hardly noticeable.
# negative neg positive Bestelltes Produkt: Vegan Avocado Burger & Cola. Die Cola war nicht lieferbar, sehr netter und professioneller Anruf von Tino bzgl. Ersatzgetränk. Lieferung: alles super. Das Essen: Zu viel matschige Füllung für den Burger, deshalb kam alles raus (siehe Foto). Dafür seid ihr wirklich sehr großzügig mit Avocado und die war megalecker. Das Burgerbrötchen ist ganz schlecht: weich, chewy, industriell, wirkt sehr schlecht und billig. Noch eine Idee: um etwas Branding aufzubauen könntet ihr doch für jede Marke eine coole Karte designen, die man mit seiner Lieferung dazubekommt. Oder einen Sticker. Aktuell gibt es ja praktisch kein Branding und dann kriegt man noch die Status-SMS von GreenGurus und der Fahrer meldet sich mit GreenGurus beim Klingeln. Das kann natürlich irritieren.
# positive neu positive Ich hatte einen Pulled Chicken Burger mit Tortilla Chips (Beilage). Lieferung kam recht schnell an, freundlicher Fahrer, Essen war noch warm, Geschmack ist auch ok. Was nicht so gut lief:
# positive neu positive * Delivery time was okay, roughly 35 min.
# negative neu negative Delivery to late
# positive neu positive Schnelle und freundliche Lieferung, Essen schmeckte prima und war noch etwas warm. Deutlich teurer als der Durchschnitt in der Gegend (
# negative neg neutral Massaman und Paneng Curry. Das war jetzt nach meiner ersten Burrito Bowl die zweite Mystery Bestellung. Im Paneng Curry war aus irgendeinem Grund sehr viel Käse drin (richtig gelesen). Mit jeden Löffel konnte ich eine Vielzahl Käsefäden aus dem Curry ziehen. Interessante Kombi, die nicht funktioniert. Kann man auf gar keinen Fall Kunden so liefern. Noch krasser war jedoch das Massaman Curry. Da ist noch etwas mehr schiefgelaufen - auf der Reisschicht (Reis war nicht durchgekocht), war eine festere Maße, darauf ganz ganz wenig Soße, die auch sehr dickflüssig war. Ganz seltsamer Geschmack, das kann unmöglich so geplant gewesen sein. Das Käse Paneng war von den beiden das deutlich 'leckerere' Gericht. Ich hatte das Massaman vor Wochen schonmal vor Ort gegessen und es hat recht gut geschmeckt. Hier ist schlicht und einfach gewaltig was schiefgelaufen. Nach dem beim Burrito Bowl damals die extra bestellte Guacemole vergessen wurde, fehlte auch diesmal wieder die extra bestellte Chilisoße. Finde euch als Unternehmen echt sympathisch und wünsche euch viel Erfolg in Zukunft aber ihr müsst dringend an euren Abläufen arbeiten. Das war die vll. schwächste Lieferbestellung, die ich bis dato hatte und ich bin jemand, der sich nie im Restaurant beschweren würde, sondern einfach nie wieder hingehen würde, aber wenn ich hierfür diese Summe bezahlt hätte, hätte ich richtig Stress beim Restaurant gemacht. Bitte auch nicht vergessen, die Summe auf mein Konto zu überweisen. Auf meine August Summe warte ich nämlich noch. VG
# negative neu positive Order was more than 46 minutes late. Customer wasn't able to reach the customer support via phone and canceled the order in the end.
# n/a neu negative Got the chicken burritos and quesadillas.
# negative neu negative Late deliveryYou messed up all the salsas and dips (avocado was for the bowl and salsa for the chips).
# positive neu positive Took around 45min. Salad is tasty, fresh,
# negative neu negative although a bit small.
# negative neu negative Burritos zu trocken! Sour Cream wurde vergessen
# negative neu negative falsche Lieferung. Reis statt Quinoa
# positive neu positive The delivery was quick.
# positive neu negative White Pizza and Minestrone soup.  There wasnt any Minestrone left, so they called me. Instead they offered and brought 2 other soups, not sure which flavours. I like the mushrooms and goat cheese on the pizza...
# positive neg positive Ich habe das rote Thai Curry mit Tofu bestellt. Es hat RICHTIG gut geschmeckt und war perfekt scharf. Der Reis war nicht genug gekocht und daher etwas hart. Die Portion war sehr groß, daher hat es für zwei gereicht, was ich gut fand. Wie immer denke ich dass ihr ein wenig Branding machen könntet, der Fahrer meldet sich mit "Hallo", die Tüte ist nicht bedruckt, die Box mit dem Essen ist nicht bedruckt, dabei gäbe es so viele Chancen die MoodyMonkey Marke zu platzieren.
# negative neu negative Got the yellow beets and avocado sandwich and it was dry, hastily put together and small. Did it even have beets? When I looked at it, it didn't seem like something that invited me to eat it; and upon eating it, the taste didn't move me to keep going either.
# negative neu negative Guys, when I had the Tikka Masala Curry on the day we launched IndiaLab, I thought it would become my new favourite dish in all of GuruCollective. I had it again today and I'm really disappointed. It's a bit tangy / sour, the sauce is not as flavourful anymore and the tofu tasted like nothing so I didn't even finish it. I wouldn't order from this restaurant again. (Rike)
# n/a neu negative I ordered twice: Pizza White, Pizza Green & Pizza Funghi + Tonno Salad
# negative neu negative Unfortunately, all pizzas were cold / seemed to be a bit older. , but: Pizza White - Bechamel, where are you? & Pizza Green, very dry and needed another portion of salt & pepper
# positive neu positive Habe einen Salat und ein Sandwich bestellt. Beides sehr lecker und die Zutaten wirkten sehr gut.  Lieferung alles super. Wie immer: macht mal etwas Branding bei den Produkten mit rein. :-)
# negative neg neutral Allerdings war beides nicht besonders viel und die Preise dafür fand ich entsprechend sehr happig (5 Euro für zwei Scheiben Toast mit Käse und Zwiebeln).
# negative neu negative Vegan Burger and Potato Salad.Burger was a little bit dry. But I actually did not like the Salad - had very little taste and it tasted strange.
# positive neu positive Delivery was okay.
# negative neu positive Kalt . <U+263A> Schönen Feierabend.
# negative neu negative but this time portions were much much much less than previous times for some reason and for the same price...
# negative neu negative Customer: My curry came out like a compressed log of rice with a carrot stick and a peanut in it. For some reason I felt personally offended by how bad it was.
# n/a neu negative es ist nun wieder passiert, dass meine Bestellung nicht richtig geliefert wurde!
# n/a neu negative Delivery too late because of not enough drivers but people were generally understanding when I called them in advance.
# negative neu negative Maybe a little too small. One bread was missing.
# positive neu positive Punctual. Very tasty. Would recommend.Best order sofar.
# negative neu negative A little toosmall the salad. One bread was missing.
# positive neu positive delivery was on time on most orders, delayed ones got called and were understanding
# negative neu positive Thai Curry Peaceful Panang. Quantitiy: a lot, however i did not like it: monotonous  tase, 90% rice, 5 cashew nuts, 5 leaves of spinach, 3 tofu dices - thats it. Recomendation: less but more mixture of ingredients.
# negative neu negative one missing wrap
# negative neu positive just the dressing was not the one that I saw on the picture of the platform. With the right dressing the bowl would have tasted better.
# positive pos neutral Lieferung super, Essen super (Avocado Chicken Salad),
# negative neu positive den Preis finde ich etwas hoch und, wie immer: es gibt überhaupt kein Branding bei den Verpackungen / Tüten / .... .
# negative neu positive Customer feedback: but the salads are really tasteless(I found some tiny stone´s in my salad-hmmm) ..
# negative neu negative one missing bowl
# positive neu positive I ordered the Red Hot Chili burger with pulled pork. The flavour and level of spiciness were good,
# negative pos negative but the pulled pork was a bit dry. The burger needs something to add some secondary flavours. Red coleslaw and pickle slices would improve it a lot.
# negative neg neutral in dem heute von mir bestellen Salat waren Trauben, die ihre besten Tage schon lange gesehen haben….nicht so lecker (s. Anhang). Ich finde, sowas sollte dringend vermieden werden, vor allem, wenn man sich mit der Frische der angebotenen Speisen rühmtJ
# negative neg neutral Tagliatelle Manzo e Funghi: Sauce was watery, no parmesan, no basil, just corn and paprika instead. No salt at all.
# positive neu positive Customer: Lots of gluten free options! Very tasty chilli sin carne.
# negative neu negative The amigo bowl was tasteless by itself though and the lime dressing did not go well with it
# negative neu positive But pasta was not stirred, so it was a big clump of noodles that were all sticking together. And there were really too many capers to eat.
# negative neu positive Butter Curry + Kofta, is ok, but not very convincing - it tastes a bit too sour, which is ok, if it wasn´t the-out-of-the-can kind of sour. Koftas were on the edge to be raw, a bit rosy in their core.
# negative neu negative I ordered Chickpea Lemon Salad, which was a little bit to sour for my taste,
# negative neu negative portion size way too small
# positive neu positive tasted good though
# negative neu negative wrong burrito
# negative neu negative Not warm enough, though
# negative neu negative but it wasn't wrapped as shown in the manual ;) so it was a bit annoying to open
# negative neu positive Looked nice, but broth was more or less tasteless. Dish was the dashi-sesame.
# negative neg neutral meine Kolleg*innen und ich habe schon mehrfach bei Euch bestellt und waren bislang immer zufrieden. Heute habt Ihr uns aber leider ziemlich enttäuscht. Das Essen kam leider erst gegen 14:30 Uhr und damit zwei Stunden nach der Bestellung. Das wäre ja nicht das Schlimmste. Die beiden Salate waren dann aber auch noch sehr spärlich gefüllt. Quinoa und Brokkoli waren kaum vorhanden. Erbsen fehlten vollständig. Das Dressing war viel zu dünn und leider geschmacklos. Wie kann das sein? Dafür sind 7,99 € zu viel Geld. Ich hoffe, Ihr findet zu alter Qualität und Verlässlichkeit zurück.
# negative neg neutral Ja, es war alles ok. Außer, dass bei einem Curry keine Sauce dabei war sondern nur Reis und Fleisch.
# n/a neu positive [Thai Curries] Peaceful Panang // Kaeng Phanaeng (pikant), mit Sesam-Tofu, mit Cashew-Kerne, TASTE NIRVANA Real Coconut Water - Pure 0,28l, Apinya Thai Chili Sauce (Original).
# negative neu negative Pizza was really cold and not really tasty =( Margharita
# negative neu negative Chicken Lightening - unfortunately not warm anymore :(
# negative neg positive Die Pizza war komisch - praktisch keine Tomatensauce, dadurch sehr trocken und (vermutlich durch die Marinade der Pilze) sehr süß. Also eher Ahornsirup-Pilz Pizza als Pilz mit Tomatensauce. Das geht sicher besser.
# positive neg positive Vegan Waldorf Salad und Pizza Funghi: Der Salat war lecker (hab mich nur gewundert dass Artischocke drin war, aber ich liebe Artischocke).
# positive neu positive Pizza White und Vegan Waldorf Pizza: beide superlecker - großes Lob! Lieferung hat auch perfekt und schnell geklappt. :-)
# negative neg positive Customer: "Essen war mal besser aber das harte WEISSBROT ging garnicht."
# positive neu positive Chili Cheese Burger and Chili Con Carne, that became Chili sin carne since there was no meat available. Overall nice,  .
# negative neg positive jetzt habe ich es zum vierten Mal mit Euch versucht und wirklich jedes Mal ist etwas mit der Bestellung nicht in Ordnung. Ich finde Euer Konzept klasse und bin auch gerne bereit, Eure Preise zu zahlen, die Sachen kommen mit dem Rad oder E-Roller, und das ist toll so. Aber es ist wirklich immer was. Jetzt am Wochenende hatte ich eine falsche Bowl, überhaupt habt Ihr in fast jeder Bowl Quinoa, manche vertragen das Zeug einfach nicht. Man kann das von außen nicht checken, da die Bowls alle gleich aussehen, nicht mal die Lieferanten wissen, was drin ist. Und neulich hatte ich Wraps, die den Namen nicht verdient haben, allenfalls ein paar traurige Rucolablätter waren darin, geschweige denn irgendeine Füllung. Das muss regelmäßiger, verlässlicher werden, sonst klappt das einfach nicht.
# negative neu positive The soup was heavier and thicker than I was expecting from a minestrone, and I also found it to be a bit over-salted, though the overall flavor was OK. I am used to a lighter broth and more veggies in a minestrone and so I probably wouldn't order it again.
# positive neu positive Gnocchi Calabrese where really good
# negative neu negative I ordered Mild Massaman with Chicken and a Singha beer. Unfortunately I got the Massaman without Chicken and a Krombacher instead of the Singha...
# positive pos neutral I feel that the taste of burritos has improved a lot!
# positive neu positive Delivery fast.
# negative neu negative Pizza a but dry
# negative pos negative eine falsche bowl wurde geliefert. in einem Salat fehlte Avocado. zudem gab es eine allergische Reaktion auf den sweet potato wrap (gegen angegebene Allergene: Weizen, Mandeln, besteht aber keine Allergie!)
# negative neu positive [FOOD ISSUE] There was a piece of plastic on the pizza.. the pizza wasn't as warm compared to other deliveries, the Margarita was very basic the cheese melted as if it were in a microwave... The chicken salad with avocado was fresh and worth it's price.
# negative neu negative I ordered the Tom Kha and the Mean Green Curry - unfortunately the soup was cold when it arrived, I ordered it with cashews, but only found three of them. Some more would have been nice.
# negative neg neutral [FOOD ISSUE] Kunde war bei vorheriger Bestellung zunächst verwundert über das neue Brot – Weißbrot anstelle von "richtigem" Brot. Jetzt beschwert er sich über Qualität des Weißbrots (loch in Brot): "Ich kann verstehen das man ein Unternehmen mit der Zeit optimieren muss. Aber wenn das so aussieht dann lasst es lieber weg."
# negative neu negative Proteine Bowl: there was one piece of extremely hard substance. I think it was natural, but still.
# negative neg positive [FOOD ISSUE] Vegan Sundance Burrito: much too soggy, rolled very loose so everything fell out. The vegan chorizo doesn't taste like much, shouldn't there be a new recipe?
# negative neu negative one missing drink
# negative neu negative [FOOD ISSUE] Green Pizza: without Zucchini, Rucola was old, pizza was cold and squishy
# positive neu negative really delcious and filling - chicken ginger ramen.
# positive neu positive [FOOD ISSUE] Avocado bowl - food was good,
# positive neu positive Everything was good. The burger I ordered was not available that night, but I was called promptly and chose the Avocado Burger instead.
# positive neu positive Tasty and fresh
# n/a neu negative [FOOD ISSUE] [TIME ISSUE] [2017-10-18] For me, Tom Kha and Thai-Curry - Mean Green Rindfleisch (for a friend, Reckless Red  Sesam-Tofu).
# positive neu positive Food was good,
# positive neu positive Protein Bomb - great salad
# negative neu negative [FOOD ISSUE] Hi, today again wrong order. We ordered 2 BLT wraps but received 2 sweet potato wraps.  but almost every order I’ve made has been wrong!
# positive neu positive Food is really good guys,
# positive neu positive Avocado burger was outstanding--there was more meat than the last time I ordered it, and it was definitely hearty enough this time around.
# negative neu negative [FOOD ISSUE] I had bolognese pasta: cold, just a bit of meat, not tasty
# negative neu positive The broth could be a bit more spicy/tasteful.
# negative neu negative [FOOD ISSUE] customer got burrito instead of the bowl she ordered - accepted it anyway - but - found a thick long black hair in it... (said she will send a photo of it, but haven´t yet, til the end of this shift)
# positive neg positive aber es war schnell da und Sara war sehr freundlich.
# n/a neu positive Ordered the classic with vegan chorizo and coleslaw.
# negative neu negative [FOOD ISSUE] [PACKAGING ISSUE] [TIME ISSUE] cold, 2 hours late
# negative neu positive not so great: please mix the ingredients better so that one side of the burrito is not dry as sand (quinoa) and only one side is juicy (guacamole) when biting in
# negative neu negative [FOOD ISSUE] [2017-10-20] Already added this one, but now there´s a photo as well - Customer found a thick long black hair in her burrito - btw. she ordered a bowl, but got a burrito.
# negative neu positive Hokkaido Ramen was unexpected hot and didn’t have any broth (unexpected as well)
# positive neu positive The taste got much better over the last months!
# negative neu negative [FOOD ISSUE] I ordered a Chicken Lightning Burrito. The burrito I received had a Chicken Lightning sticker on it but was actually a Tofu burrito.
# negative neu negative [FOOD ISSUE] Habanero salsa was missing, small portion compared to a burrito
# positive neu positive Reckless Red was really good,
# negative neu negative but the chicken pieces were way to large
# negative neu negative [FOOD ISSUE] kalt und ohne Nudeln
# positive neu positive mild massaman tasted good (probably a bit spicy), but lookwise not even close to the one i had earlier this week.
# negative neu positive Not a nice assembly, no greens on top.
# positive neu positive Good & very tasty sauce (yellow mellow)
# n/a neu positive [TIME ISSUE] Customer happy about us calling him to explain delay in delivery (didn't take it for granted)
# positive neu positive [FOOD ISSUE] endlich habe ich es mal geschafft,bei euch zu bestellen und WOW schmeckt das Essen gut und es war so schnell da!!!
# negative neg positive [FOOD ISSUE] [PACKAGING ISSUE] der versprochene Smoothie war nicht dabei, Pizza war kalt! Es wäre gut eine andere Verpackung zu benutzen, damit sie warm bleibt
# positive neg positive [FOOD ISSUE] [2017-10-13]  1x Moody Soup // Tom Kha: Die Suppe war gut. Die Portion war erstaunlich groß. Die Zutaten passten gut zusammen.
# positive neg positive Bestellt hatte ich: 1x Suppe - Vegan Chili Sin Carne und 1x Burger - Tex Mex Burger mit Protein: Pulled Chicken mit Cheese und Extra-Pico de Gallo Sauce: Beide Gerichte haben super gut geschmeckt. Die Portionen waren groß. Die Suppe habe ich schon einmal bestellt und sie ist qualitativ immer top! Der Burger schmeckte mit den Extras richtig gut und hatte eine gute Konsistenz und Form, was wohl auch der neuen Verpackung geschuldet war. Durch den Pappkarton war der Burger nicht so zusammengedrückt wie vorher hier angekommen. Beide Gerichte sind in heißem Zustand bei mir angekommen. Der Lieferservice war wie immer schnell und sehr freundlich.
# negative neu negative [FOOD ISSUE] the curries were "ice-cold" as they arrived to the customer. (i guess they have been traveling a long way in the drivers bag, before they arrived - drivers from Rochstr. forced to take too many orders at once, so the food gets cold, til they arrive to the destination)
# positive neu positive geschmacklich wieder top!
# negative neg neutral The food was not delivered. I ordered through two websites at the same time (Pizza.de and Lieferheld) and only the one through Pizza.de arrived. I tried to call but after two calls nobody answered. Bummer!
# negative neg positive [FOOD ISSUE] [2017-10-22] Eine Pizza war ziemlich warm, die andere kalt. Die Tomatensoßen auf den Pizzen waren nicht so lecker, ziemlich süß und schmeckten eher wir aus der Verpackung. Paar Gewürze wie Oregano/Majoran und weniger Süße würden die Soßen schmackhafter machen. Die Pilze schmeckten auch wie Dosenpilze, daher hat die Pilzpizza nicht so überzeugt.
# positive neg positive Die Pizzen kamen früher an als angekündigt.Die Größen der Pizzen war gut. Alles in allem waren die Pizzen aber in Ordnung.
# negative neu positive The only thing I'd say is that the cherry tomatoes kept falling out of the sandwich when I tried to eat it, and slices of larger tomatoes might work better. That's just a small thing, though.
# n/a neu positive Ordered the Sweet Potato Wrap and the Eureka Bowl.
# negative neu negative I ordered 2 beers but only got one. I think this is because of the confusing bill which I attached, it figures 1 x beer but there was also one included in the menu.
# positive neu positive Very reliable delivery and salads as always very tasty.
# negative neg positive [FOOD ISSUE] Ich habe Tagliatelle Aglio und Tagliatelle Manza (ohne Rindfleisch) bestellt. Die Lieferung hat gut geklappt, auch der Sonderwunsch "ohne Rindfleisch" hat funktioniert. Statt Tagliatelle waren allerdings beide Gerichte mit Rigatoni zubereitet. Die "Tagliatelle" Aglio Olio war eine große Enttäuschung: es war einfach Pasta, die in UNMENGEN Öl schwamm (siehe Foto). Das war wirklich nicht essbar und außerdem eine riesige Ölverschwendung.
# negative neu positive [FOOD ISSUE] [2017-10-30] somehow there was paprika in my ramen (?!) and the chunks were huge. i couldnt taste the miso flavour just spiciness
# negative neg positive [FOOD ISSUE] [2017-10-19] Customer: "Burritos waren eher geschmacklos, die vegane Chorizo ist einfach nur Tofu (das sollte wirklich als solcher bezeichnet werden) und die Guacamole war nicht wie erwartet im Burrito sondern als extra dabei. Ich vermute, die Burritos werden vorbereitet und dann erwärmt. Traut euch mal an Gewürze ran!"
# negative neu positive [FOOD ISSUE] too hot
# positive neg positive Es hat alles gut funktioniert und das Essen (die beiden pikanten Currys) waren lecker und angenehm scharf. Ich finde es gut, dass ihr jetzt zumindest ein kleines bisschen Branding habt, durch die Aufkleber mit dem Gericht-Namen, der die Becher verschließt.
# n/a neu positive [TIME ISSUE] Too many delays and grumpy customers due to massive order amount and too less drivers
# negative neu negative The Naan was super hard and dry-- :( (Because if the very low-quality of the naan I wouldn't order again from IndiaLab.)
# positive neu negative [PACKAGING ISSUE] [2017-11-05] I had a chicken avacado salad. The chicken and bacon were both very good.
# negative neu positive The one big issue is that I ordered a soup, too, and it was forgotten. I can confirm it was on the receipt that was stapled to the bag, so it doesn't seem like a pizza.de issue.I'm not so sure about the dressing--I can't tell if it's made up of *only* mayo or just mostly mayo, but it's definitely more mayo-heavy than what I am used to in a salad dressing.
# negative neu negative [FOOD ISSUE] -The figs are too big and also still had part of the stem attached to it, making them difficult to eat
# negative neu positive [FOOD ISSUE] [PACKAGING ISSUE] Wrapping warm sandwiches in tin foil is really bad: ciabatta bread was incredibly soggy
# negative neu negative [FOOD ISSUE] wakame salad: portion too small, customer upset, kitchen used big boxes instead of small ones for the usual amount of food so it looked less. had to refund the order.
# negative neu negative [TIME ISSUE] [2017-11-12] 8 mins too late...
# positive neu positive Eureka bowl: very good
# negative neu negative [FOOD ISSUE] Vegan Waldorf Salad had a few bad grapes (brown squishy). Please check them before putting them in.
# n/a neu positive Every thing went smooth today. Thanks a lot!
# negative pos negative [FOOD ISSUE] [2017-11-05] Customer: "Edible but otherwise bad. The burritos taste anything but Mexican (or even Tex Mex), the salsa verde honestly tasted like it had tons of cumin (?!) inside it and no green tomatoes, the tortilla chips (3eur not including salsa or guac) are basically super-expensive Doritos. Shockingly they have an 80% positive rating on Deliveroo, is that made up? Or have all those people never tasted a proper burrito in their life before?"
# positive neu positive [FOOD ISSUE] [2017-11-09] 1x Pizza Black (mit Mozzarella) und Suppe Minestrone:. Der Belag war aber einzigartig, geschmacklich top.
# negative neg positive Die Pizza war nur halb so groß wie auf der Webseite angegeben, daher etwas klein. Die Suppe war geschmacklich sehr tomatenlastig und das Gemüse war sehr weich gekocht.
# negative neu negative [FOOD ISSUE] The soups were cold., although they felt warm from the outside :(
# negative pos negative [FOOD ISSUE] Unfortunately it was really bad... I would try the other bowls just to try, but would never order these two again. Especially the one with quinoa as the sauce was super sour and with very simple ingredients. I could make a better one myself... :( sorry to say that guys!
# positive neu positive [PACKAGING ISSUE] Reckless Red with Cashiu, Ice cream. The delivery was on time and divided into two separate bags, which I liked (one for the food and one for the desert).
# positive neu positive Took 40 Min. which is fine for a Friday night and food was delicous. Well done!
# negative neu positive The only little "complain" is that the tomatoes on top were quite watery so in the end there was quite some water in the last spoons of the food.
# negative pos neutral [FOOD ISSUE] [PACKAGING ISSUE] [TIME ISSUE] Driver informs the dispatcher that the ordered drink is not delivered with food -"Drink also missing for Charlotte, please refund her" - (not the 1st time, without informing the dispatcher and asking the customer what he/she wishes instead of the drink that´s not available) - so the dispatcher calls the customer, offers a voucher (because partial refund is not available with Lieferheld), but the customer says - "A voucher for your restaurant? No, certainly not, thank you!" - The dispatcher apologizes once more and kindly offers a full refund. Customer accepts the offer.
# positive neg neutral schmeckt gut, wird kostenfrei geliefert und ist vermutlich eines der gesündesten Sachen 'Fertigessen' die man zum Mittag käuflich erwerben kann
# positive neu positive Gesundes essen, direkt bei Arbeitsplatz geliefert and zwar ohne chic-chac. Ich finde diese Leistung ganz praktisch. Ich hatte gerne grosser Wahl, weil nach 2-4 Woche, ist es schon langweilig um gleiche salat zu essen.
# positive neg positive leckeres essen und der shop ist einigermassen einfach. gut waere wenn ihr in meinem profil alle nicht benutzten rechnungsadressen löscht (nur schlegelstrasse 9, 10115 berlin lassen) und die checkbox fuer den newsletter weglasst die man bei jeder bestellung neu wegdruecken musst. danke!
# positive neg positive Weil eure Produkte großartig schmecken und die frische Zubereitung einfach für sich spricht.
# positive neg positive Weil alles gut schmeckt und die Bestellung einfach ist und klappt. Habe Euch schon oft weiterempfohlen.
# positive neu positive Es ist einfach unglaublich lecker, gesund und sehr bequem. Einziger Punkt .- für nicht ganz so gut Verdiener etwas teuer. Aber so ist das bei frischen Zutaten :)
# positive neu positive Geiles essen und kostenlose lieferung
# positive neu positive Frisch, schnell geliefert, Mindestbestellwert, der für Einzelbesteller funktioniert. Danke.
# negative neu positive Eigentlich immer alles perfekt könnte nur etwas günstiger sein und heute waren Haare in meinem Salat
# positive neu positive Salat war ok.
# positive neg neutral Dies war meine zweite Bestellung. Das Essen war wieder sehr gut. Mein Smoothie war diesmal etwas dünner als bei der ersten Bestellung, das war etwas schade. Dennoch würde ich euch weiter empfehlen und selbst nochmal bestellen. Schade das es bei euch kein Fleisch gibt.
# positive neg neutral Generell war alles gut.
# negative neu negative Leider wurde das extra bestellte Brot zum Salat vergessen :-(
# positive neg neutral War alles frisch und lecker,
# positive neu positive Delicious and healthy. The Blueberry and Cocoa smoothie is to die for.
# positive neg neutral Das Essen war in Ordnung. Ohne die Sauce hätte es gar nicht geschmeckt.
# negative neu negative Dazu wurde mein Avocado Topping komplett vergessen.
# positive neu positive Gutes Produkt! & packaging ... passt
# positive neu positive Gute Zutaten , fairer Preis , Portionen gut!
# negative neu negative Leider waren aber beide chilies gestern kalt bei Lieferung :( lg
# positive neg neutral War Mega lecker, frisch
# negative neu positive More than 90 minutes to deliver the food
# n/a neu positive Immer top. Alles!
# negative neg neutral Ich hatte ein Bowl bestellt mit veganer extra Beilage - stattdessen aber Käse bekommen. Das ist mir schon 2 mal passiert bei euch (einmal war kein Brot da, ein anderes mal gab es Bohnen anstatt Süßkartoffeln) nur heute musste ich wegen dem Käse mein Mittagsessen leider verschenken :'(
# negative neg neutral Die Portionen sind ehr überschaubar.Portionen könnten etwas größer sein.
# positive pos neutral Zutaten super.Sogar mein Freund, der Fleisch isst, hat den Salat aufgegessen. Ansonsten super.
# positive neg positive Das Essen selbst war recht lecker.  Am Fahrer lag es nicht, der war schnell, ist ein Freund von uns und schon extra vorsichtig mit der Tasche umgegangen.
# negative neg neutral The packaging broke and leaked all the food out twice in a row, this is perhaps something to look into.
# positive neu positive Food was good.
# negative neg neutral Essen kam deutlich zu spät und war EISkalt!!!
# positive neg positive Das Essen war wirklich lecker und die Lieferung ging schnell.
# negative neu negative Bestellung erst auf Nachfrage bearbeitet, versprochener smoothie vergessen
# positive neu positive Food was tasty and delivered on time:)
# negative neg neutral Ich habe 3 burritos bestellt aber nur 2 bekommen, noch dazu hat bei einem die extra bestellte guacamole gefehlt...
# positive neg neutral Essen war lecker,
# positive neu positive Geschmacklich gut.
# negative neg neutral Aber die burritos die ich gerne essen gehe sind einfach viel vollgepackter. Im gringo burrito schien viel Luft zu sein.
# negative neg positive Ungewürzte Pappe. Das beste waren die gekauften Tortilla Chips, da kann man bei der Zubereitung nichts falsch machen.
# negative neg neutral Extra tortilla und sour cream für zweimal Burritos war nicht mit die Bestellung.
# positive neg positive War sehr lecker und war schnell geliefert
# positive neg neutral Veggie Thunder war lecker.
# negative neu positive Essen okay, hätte etwas kräftiger gewürzt sein können.  Preis etwas hoch.
# negative neu positive Burittos were very blant. One buritto didn't have extra beans that we ordered.
# negative neu negative Schlechtes Essen, teile der Bestellung vergessen
# n/a neu positive An sich gut, aber “build your own“ ohne (sichtbare) Möglichkeit Fleisch zu wählen.
# positive neu positive Gutes Essen, simpler Shop, kostenlose Lieferung
# positive neu positive Essen ist gut.
# positive neu positive Immer frisch, immer pünktlich – weiter so!!
# positive neg neutral Essen is lecker, allerdings ist die Auwahl ein wenig klein. Ich würde mir die Bowl auch gern selbst zusammenstellen können
# negative neu negative Zwei mal falsch geliefertes essen
# positive neg positive Trotzdessen es schon ein paar Probleme mit meinen Bestellungen gab, war ich immer sehr zufrieden. Die Servicemitarbeiter waren immer sehr freundlich und haben sich sofort bemüht ein Lösung zu finden. Außerdem ist die Qualität des Essens sehr gut. Mir gefällt besonders die begrenzte Produktpalette. Dabei fällt mir die Entscheidung viel leichter.
# positive neg positive Es war lecker und frisch zu einem guten Preis.
# n/a neu positive Insgesamt gut, Checkout besser als früher, aber immer noch ein Checkout mit vielen Schritten
# n/a neu positive Ich mag den Konzept
# negative neg neutral Ich hab mich sehr auf mein Essen gefreut. Um 19.45 habe ich bestellt, um spätestens 20.45 sollte es da sein laut SMS, um 22 Uhr war es noch immer nicht da. Im Restaurant ging nur der AB ans Telefon, der mitteilen lässt, dass niemand mehr da ist und um kurz vor 23 Uhr klingelt mich der Fahrer aus dem Bett und will mir mein Essen geben.
# negative neu negative weil ihr euch leider stetig verschlechtert. anfangs habt ihr lieferzeiten unterboten, jetzt leider nur noch regelmäßig überboten. zudem ein Witz für 1,50 genau 5 kleine Würfel Süßkartoffel zu portionieren. schade war sehr großer Fan zu Beginn
# negative neg neutral Essen war mittelmäßig
# negative neg neutral Paypal funktionierte gerade nicht und die Lieferung ist fast immer zu spät,
# positive neu positive aber das Essen ist gut
# negative neu positive Weil ich hoffe, dass das Essen dann schneller geliefert wird.
# negative neu positive Burrito hat etwas geschwitzt in der Verpackung. Serviette wäre schön gewesen.
# positive neu positive Gute Qualität, frisch. Für Veganer bestimmt eine gute Option
# positive neu positive Gute Auswahl an gesunden Essen, Lieferzeit okay, lecker!
# negative neg neutral War ganz okay nun nicht das beste. Vielleicht habe ich zu viele feuchte Zutaten gewählt, aber der Inhalt war ziemlich flüssig. Ich würde nochmal was anderes bestellen und es dann wieder probieren...
# negative neg neutral Ihr habt die Preise angezogen. Geht dann für viele leider nicht mehr so häufig.
# negative neg neutral Es fehlte die bestellte Guacamole und im Burrito war nichts von Habaneros zu schmecken.
# n/a neu negative Weil der Prozess nicht fehlerfrei funktionierte
# positive neg positive Die Lieferung dauerte 40 min. Alles war frisch und noch warm. Sehr empfehlenswert!
# positive neu positive Einfach lecker eure Quesadillas!
# positive neu positive Lecker und simple Bestellung - aber ich hätte gern wieder die Desserts bitte :)
# n/a neu positive Hat mal gut geklappt, dann wieder nicht. Jetzt sind wir in einer neuen Testphase.
# negative neu negative Zweimal bestellt und zweimal was falsches angekommen Bzw was gefehlt
# positive neu positive Umweltfreundliche Verpackung
# positive pos neutral i like the salad and that it doesnt have a minimum cost anymore, because afterall the prices already went up since the beginning of green guru. thanks
# positive pos neutral Alles super! Bestelle wieder!
# positive neu positive Schnell. Warm. Lekker
# positive neg positive War frisch zubereitet und gut,
# n/a neu positive aber sonst alles prima.
# negative neu positive More than 2 hours for delivery
# positive neu positive einfach und lecker
# positive neu positive Weil es lecker ist und gesund. Etwas mehr Auswahl wäre aber noch schöner langfristig gesehen
# negative neg neutral Die Portionen könnten etwas größer sein.
# positive neu positive Ganz einfach: Weil's schmeckt! ;-)
# positive neu positive weil es praktisch ist und in der Zwischenzeit gute Qualität
# positive neg neutral Alles bestellte Essen war sehr lecker, auch die Lieferung hat immer geklappt! Weiter so!
# positive neu positive Lecker, schnell, frisch. Einmal hin, alles drin.
# negative neg neutral Sehr lange wartezeit für die essen zu kommen
# negative neu negative Prices are getting a bit expensive now, so i don't use so often,
# negative neg positive Das Essen entspricht nicht der Beschreibung, welche hochwertiges superfood Essen verspricht. Am Ende waren die Bowls, die wir bestellt hab n nichts weiter als ein billiger Salat, den ich zuhause besser hinbekommen hätte.
# negative neu positive Lieferung eine Stunde zu spät. Produkte entsprechen nicht den Texten zum Gericht (z.B. Edamame waren keine, sondern Zuckerschoten). Nach dem Essen hungrig aufgestanden.
# positive neg neutral War sehr lecker.
# positive neu positive Weils gut schmeckt und zuverlässig gebracht wird.
# negative neu positive Most underwhelming burrito i have had in a long time.
# negative neu negative min late and not the extra guacamole i ordered.
# ...
# negative neg neutral Es gibt gute Pizzen in Berlin und es gibt nicht so gute Pizzen in Berlin. Und es es gibt fürchterliche Pizzen. Eure Pizza war eine der drei schlimmsten Pizzen meines Lebens. Wenn ich eure Pizza weiter empfehlen würde, würde ich mich schuldig machen.
# positive neg neutral War lecker !
# negative neu negative Chicken zu trocken, teilweise harte, unkaubare Streifen dabei. baked beans sauce zu sü und insgesamt verkocht. coleslaw ok, Kartoffelsalat nicht genug gewürzt. Generell fiel auf, dass Essen untersalzen war.
# negative neu negative Overpriced, small and plain portions
# negative neg neutral The most disappointing meal I have had this year, why did you pour the curry in with the rice? Also adding my number to a mailing list is unacceptable
# negative neu negative i ordered pulled pork and recieced chicken which was dry. the burger was squashed and not nice at all as well as a bit cold. it was very expensive for what it was
# negative neu negative Too small portions and lukewarm
# positive neu positive Sehr guter Aufbau der Webseite, ausgezeichnetes Angebot, schnelle Lieferung, guter Service.
# negative neg neutral Die vegane Chorizo war gar nicht lecker.
# n/a neu negative Terrible.
# negative neg positive Essen war lau warm als es ankam .... Und die Bürger waren ein bisschen klein und es hat ein bischen liebe zum Detail gefählt
# negative neg neutral Webseite war zeitweise nicht zu erreichen, Account vom Kollegen funktionierte nicht, musste ich neu anlegen, Salat konnte nicht vorbestellt werden, da im Shop ausverkauft, mussten erst anrufen und wieder freischalten lassen, Lieferung kam zu spät, Preise steigen seit Monaten,
# positive neu positive Weil SUPER-SUPER-lecker und gesund und einmalig :-)
# negative neg neutral Weil ich das Dressing zu sauer fand. Es schmeckte leider nur nach Limette, war sehr sauer, so dass ich kaum etwas Anderes schmeckte.
# negative neu negative lasch gewürzt, wenig gemüse, viel soße und reis
# n/a neg neutral Es war genau die Art von Pizza, die ich gesucht hatte.
# positive neu positive Das burrito war frisch und das cola original.
# negative neu negative Ich bin weiterhin sehr zufrieden mit dem Essen, allerdings habt ihr seit einiger Zeit regelmäßig irgendwelche Lieferschwierigkeiten (ihr liefert das falsche Essen oder die falschen Smoothies). Auf lange Sicht gesehen nervt das ein wenig. Und es wäre cool wenn ihr euer Salatangebot öfter als 4x im Jahr durchwechselt.
# positive neg positive Sehr kreativer Belag, geschmacklich sehr gut, hochwertige und frische Zutaten und absolut fairer Preis. Auch die Lieferung war pünktlich. Ich will noch eine :3
# negative neu negative Falsche Pizza als Bestellte untergeschummelt.
# positive neg neutral War trotzdem lecker.
# n/a neg positive Die Auswahl ist nicht riesig und es sind viele Zutaten dabei, die Blähungen verursachen. Das ist im Business nicht so gut. ;-)
# negative neg neutral aber das war die dritte mal ich mehr als 1h gewartet habe.
# negative neg neutral Ein bisschen teuer und die Lieferung hat es sehr lange gedauert, die Portion war auch ein bisschen bescheiden für den Preis.
# negative neg neutral Die Suppe hat komisch geschmeckt, fast als wäre sie schlecht. Das Fleisch beider Sandwiches war komplett geschmacklos. Gewürze? Fehlanzeige. Außerdem stimmt das Preis-Leistungsverhältnis nicht.
# negative neg positive Das Essen kam kalt an. Der optische Eindruck war nicht besonders. Die Burger Brötchen war klein und der Preis dafür zu hoch. Die Idee an sich ist gut... aber da ist noch viel Luft nach oben! :/
# positive neg neutral War lecker
# positive neg neutral Es war seh sehr lecker
# positive neu positive Ordering process was seamless and food is tasty!
# n/a neu negative Der Checkout Prozess ist unübersichtlich und verwirrt mich.
# positive neu positive Lecker< und zuverlässig. Nette Leute
# positive neu positive Das Essen schmeckt frisch und lecker, ist besonders und wird schnell und freundlich geliefert. Vielen Dank!!!
# n/a neu negative Zu unübersichtlich und der vorgewählte Newsletter-SignUp ist extrem unfair und nervig.
# negative neu negative In my last order, the quality and quantity were disappointing. The food looked like hastily prepared stuff without much care for quality and presentation.
# negative neg positive Schon recht teuer, obwohl geschmacklich nicht vollends überzeugt. Gleiches gilt für die baked beans.
# negative neu positive Einfach keine Qualität
# positive neg positive Überraschend geiler Burger. Ihr könntet noch paar mehr Beilagen (zB Pommes) und Soßen anbieten (vom Burger allein wird man nicht wirklich satt und Tortilla-Chips sind nicht zum Liefern geeignet, weil sie durchweichen), aber die Qualität des Essens ist einfach der Hammer.
# negative neg neutral Die Burger waren viel zu klein und dementsprechend stimmte das preis-leistungsverhältnis nicht.
# n/a neu positive Alles tip top!
# negative neg neutral pizza war sehr geschmacklos
# positive neg positive Das Essen ist sehr lecker und "außergewöhnlich", die Lieferung ging schnell
# positive neg neutral Burrito war lecker, Zeit war auch in Ordnung.
# negative neg neutral Stunden gewartet,  natürlich war das Essen kalt.
# n/a neu negative It was terrible.
# positive neu positive Sehr lecker und gesund. Das hat aber seinen Preis.
# positive neg positive Die Bürger kamen pünktlich.
# negative neg positive Allerdings war der texmex Burger sehr sehr trocken und fast ohne die angegebene Soße. Allgemein war das preis/Leistungs Verhältnis wirklich alles andere als stimming. Wir haben uns wirklich mehr erhofft.
# positive pos neutral Essen schmeckt super, Gewicht variiert leider oft ein wenig,
# negative neg positive manchmal gibt es leider ein wenig Chaos bei der Lieferung (entweder Fahrer zu spät oder falsche Salate oder Smoothies geliefert; Idee: Smoothies mit weniger Zucker anbieten (eure Hauptbestandteile und wie bei allen anderen Anbietern leider auch, sind Orangensaft und Apfelsaft). Vllt könnt ihr ein wenig mehr Gemüse untermischen, damit die Dinger auch wirklich halbwegs gesund sind und es den Menschen nicht nur vorgegaukelt wird.
# n/a neu positive ist gut, aber ist schon viel teurer geworden - eigentlich nicht mehr was für jeden Tag.
# negative neu negative pizza zu teigig, kalt, falsch belegt
# negative neg neutral Der vegetarische Burrito war etwas fade im Vergleich zu dem mit Rindfleisch.
# negative neg neutral Qualität hat extrem nachgelassen. Trocken und sauer. Ich hab die Hälfte weg geworfen
# negative neg neutral Habe einen burrito bestimmt aber eine bowl bekommen. Hat zwar gut geschmeckt aber es war ein falsches Produkt.
# positive neu positive Gute Preis & sehr lecker!
# negative neu negative Bestellungen wurden mehrfach falsch geliefert und Soßen wurden oft vergessen
# negative neg neutral Nur die Portion ist etwas klein bei den Bowls!
# negative neg neutral It was a joke. No salsa no coreander no limerice, the Salat had no dressing. If I hadn't been so hungry I would not have eaten it.
# positive neu positive Gutes und leckeres Essen . War auch noch warm . Alles top
# positive neg neutral Der Burrito war lecker,
# negative neu negative allerdings nicht pikant wie eigentlich beschrieben und dazu fast kalt.
# negative neg neutral Die Größe der Portion ist für den Preis ein Witz !!!
# n/a neu negative Sorry guys, but this was nothing
# n/a neu positive Site looks good so far
# negative pos negative super schlechte pizza. dazu noch kalt
# negative neg positive Wie bei bisher jeder Bestellung hat mal wieder was nicht gestimmt: Dieses Mal war kein Brot/Brötchen dabei, obwohl auf dem Bestellzettel auch vermerkt. (Es geht nicht um das Brot, sondern dass einfach jedes Mal was nicht passt.)
# positive neg neutral Das Essen war lecker,
# negative neu negative Kein Saltz im Essen und es schmeckt nicht gut
# n/a neu positive Gut
# positive neg neutral Er war lecker!
# positive neg neutral war alles super-lecker
# negative neg neutral der rest war leider unterirdisch
# negative neg neutral - Das Essen kam nach 90 Minuten an (bisher die längste Lieferzeit unter der Woche bei einem Lieferdienst
# positive pos neutral Weil der Shop sehr übersichtlich und das Essen super lecker ist
# negative neu positive Leider hat das Brot gefehlt. Trotzdem waren alle begeistert
# negative neu negative Das hühnchenwar trocken und das curry schlecht gewürzt.
# negative neu positive mal probiert, 2 mal entäuscht. Reis sollte immer an der Seite sein nicht unter dem curry. Kalt, matschig und nicht authentisch. Vielleicht sind meine Erwartungen als Indonesierin auch zu hoch. Toller name, doch leider ein  kulinarischer flop
# n/a neu negative Ok.... aber nicht außergewöhnlich gut oder so
# positive neu positive Food was delivered very fast but,
# negative neu negative it was cold (and it was not due to delivery time) plus it was missing guacamole and tortilla chips.
# negative neg positive Essen war lau, bis kalt und hat nicht so toll geschmeckt
# positive neu positive Pizza eigentlich top
# negative neu negative aber bei Ankunft kalt
# n/a neu positive Anruf bekommen: Tortillas würden zu spät kommen, danke für's Bescheid geben! Toll!
# negative neu negative Chicken was very dey
# negative neu positive aber hatte ehrlich gesagt diarrhe bekommen :(
# n/a neu negative I already dilled the survey yesterday. Today i received another. If you keep sending me sms withbsurvey links, ill never ever buy your food. Please stop! Its super annoying
# positive neu positive Geschmacklich pizza aber gut
# negative neg positive War geschmacklich nicht so berauschend
# positive neu positive Hat gut geschmeckt. Püntliche Lieferung,
# negative neu negative nur ein Brot wurde vergessen.
# positive neg positive Das Essen an sich war sehr gut.
# negative neg neutral Allerdings hat die Lieferung 2 Stunden gedauert und telefonisch war niemand erreichbar.
# n/a neu positive :)
# positive neg positive Weil das Essen sehr schmackhaft und gesund war
# n/a neu positive detailed, easy process
# negative neg positive Das versprochene Brot hat gefehlt, die Preise sind unverschämt hoch und meine Protein Bowl hat schäusslich geschmeckt. Zudem hat der eigentlich angegebene Käse in der Bowl gefehlt. Nie wieder!
# positive neg neutral Das burger war sehr lecker, gutes brot und originale rezept.
# n/a neu positive Top!
# positive neg positive Die Chili sin Carne war wirklich super lecker, ich würde sie uneingeschränkt weiterempfehlen.  Ansonsten war der Burger geschmacklich super, nur würde ich beim nächsten Mal Extras dazubestellen, um den Burger geschmacklich abzurunden.
# positive neu positive Wirklich lecker,
# n/a neu positive Guter Und freundlicher Kundenservice.
# positive neg positive Das Essen war sehr gut und die Zutaten waren frisch
# positive neg positive Wirklich sehr leckere Salate und Smoothies, gesunde Alternative zu den übrigen Lieferdiensten. Könnt ihr die Verpackungen einschränken? (Viel Müll)
# negative neg neutral nur leider war die Bestellung nicht vollständig.
# negative neg neutral Für den Preis sind die Portionen ziemlich klein und das Fleisch war recht trocken
# positive neu positive Einfach lecker. Genau das richtige fürs Lunch.
# negative neu negative Ich habe zu zwei bowls snack und Brot dazu bestellt und bezahlt aber nicht erhalten!
# negative neg positive Nicht mal ansatzweise vergleichbar mit anderen Ramen-Läden in Berlin, es war leider nur eine recht einfallslose Suppe..
# negative neu negative The curry seemed like something from a supermarket packet. The naan must've been a few days old - it was totally inedible. Really bad experience!
# positive neu positive Sehr leckeres und gesundes Essen, Lieferung meistens schnell und zuverlässig.
# negative neu negative Nur manchmal leider erst nach 12 Uhr in letzter Zeit. Auch passt das weiße Toastbrot nicht wirklich zum Konzept „gesunde Ernährung“!
# negative neu negative too expensive
# negative neu positive Would be good to have the rice separately not in the pot with the curry!
# negative neg neutral In meiner Suppe war quasi keine Suppe. Es war nur ein Haufen Nudeln mit etwas Fleisch und Gemüse, quasi ohne Flüssigkeit.
# negative neu negative Essen gruselig schlecht
# negative neu negative Qualität des Essens enttäuschend
# n/a neg neutral Stop spamming!
# positive neg positive Es war sehr lecker! 9 Punkte weil es immer etwas gibt was man besser machen kann. Hab aber wirklich nichts zu meckern
# negative neu negative für mich persönlich ein wenig zu wenig dressing, lieferzeit sehr lange (1std 40 min! es war allerdings ein feiertag) als wiedergutmachung extra popcorn erhalten (danke), allerdings falsche bestellung bekommen (habe schon mehrmals bei gg bestellt und jedes mal wurde etwas vergessen oder falsch geliefert :( ) ansonsten ein super konzept, weiter so!
# negative neu negative The food arrived cold and it was pretty much horrible. The burrito tasted more like bland rice and chewy chicken wrapped in a tortilla rather than an actual burrito. The chips were covered in guacamole when delivered and were soggy by the time i got them. There are hundreds of other mexican places in berlin and I'll be trying out them instead of ordering from Gringo again, sorry.
# positive pos neutral Zuverlässige Lieferung, guter Geschmack. Würde für Bio auch mehr bezahlen! Und etwas Abwechslung wäre super.
# positive neu positive Essen sehr gut! Etwas teuer ....
# negative neg neutral Es hätte ein wenig mehr der anderen Zutaten geben sollen, finde ich. Es war unwahrscheinlich viel Salat, aber z.B. nur sehr wenig CousCous.
# negative neu positive In general I like your salads but the value for money  is not that great anymore.
# negative neg positive Das Essen war gut allerdings haben wir deutlich länger als eine Stunde gewartet :(  das ist mittags aufgrund der Termine wirklich schwierig
# positive neu positive Recht lecker,
# negative neg neutral aber leidet die extra Guacamole nicht mitgeliefert.
# positive neu positive Top Geschmack
# negative neg positive Die pizzen hätten wahrscheinlich gut geschmeckt, wenn sie nicht kalt gewesen wären. So wirkten sie leider schon nicht mehr frisch.
# positive neu positive Guten Essen
# positive neu positive Weil ich euer Essen sehr lecker finde, und davon überzeugt bin
# n/a neu negative Besteelprozess etwas verwirrend
# n/a neu positive alles einfach und kein versandkosten!
# negative neg neutral Mir und meinen Kollegen hat die Dr. Miyagi Bowl nicht geschmeckt. Außerdem fehlten die Jalapenos.
# n/a neu positive Ihr seid toll!!!
# positive neu positive Mag das Essen sehr gerne.
# n/a neu positive Wann gibt es mal wieder andere Salate? Etwas mehr abwechslung ist erwünscht.
# negative neg positive avocado war noch bisschen hart
# negative neu negative Viel viel weniger Reis als bei der letzten Bestellung , für den preis Finden wir sehr unbefriedigend ! Schade !
# n/a neg neutral Bug report: Die Bestätigung deiner Bestellung wurde an {{ email }} gesendet. Sobald deine Bestellung unterwegs ist, erhältst du einen Tracking-Code per SMS.
# positive pos neutral Ich finde eure Malzeiten super lecker, leider für regelmäßige Bestellungen aber etwas teuer! ;)
# positive neu positive Geschmacklich unfassbar spannend. Ich bin weder Veganer noch Vegetarier, aber eure Wraps und Stews sind der Hammer. Dazu kommt, dass der Preis stimmt. Wir (im Office) bestellen gerne bei euch.
# n/a pos neutral weil ich euch super finde!!!
# positive neg positive Die Salate sind prima.
# negative neg positive Aber man muss sie erst stehen lassen, weil sie zu kalt sind. Und die Dressings finde ich nicht so überzeugend.
# positive neu positive netter Service, immer frisch und lecker sowie so.
# positive neu positive Top Essen und Service
# positive neg neutral Die besten Salate der Stadt! Danke Green-Gurus!
# n/a neu positive Weil ich euch schon mehrfach weiter empfohlen habe ;)

# %%
t_doc = textacy.doc.Doc("Got the chicken burritos and quesadillas.")

# %%
textacy.preprocess_text("Got the chicken burritos and quesadillas.")
# Out:
# 'Got the chicken burritos and quesadillas.'

# %%
textacy

# %%
def get_labels_from_dict(labels, min_val=0.1):
    return_labels = []
    for label, val in labels:
#         print(label, val)
        if val > min_val:
            return_labels.append(label)
    return return_labels

# %%
# for el in corpus:
#     comment = el["comment"]
#     el["predict_labels"] = predict_labels(comment)
#     el["predict_posit"] = get_emotion(comment)
# corpus[:10]

# %%
with open('results.csv', 'w', newline='') as csvresults:
    csv_labels = ['comment', 'orig_labels', 'predict_labels', 'orig_posit', 'predict_posit']
    writer = DictWriter(csvresults, fieldnames=csv_labels)
    writer.writeheader()
    for el in corpus:
        writer.writerow(el)
